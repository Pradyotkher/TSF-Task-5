# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('C:\\Users\\Pradyot\\Desktop\\matches.csv')
df=df.drop(['date'],axis=1)
df
# Out:
#         id  season           city                        team1  \
# 0        1    2017      Hyderabad          Sunrisers Hyderabad
# 1        2    2017           Pune               Mumbai Indians
# 2        3    2017         Rajkot                Gujarat Lions
# 3        4    2017         Indore       Rising Pune Supergiant
# 4        5    2017      Bangalore  Royal Challengers Bangalore
# ..     ...     ...            ...                          ...
# 751  11347    2019         Mumbai        Kolkata Knight Riders
# 752  11412    2019        Chennai          Chennai Super Kings
# 753  11413    2019  Visakhapatnam          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam               Delhi Capitals
# 755  11415    2019      Hyderabad               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.info()
# We have some null values in the following fields City,Winner,player_of_match,umpire1,umpire2,umpire3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   team1            756 non-null    object
#  4   team2            756 non-null    object
#  5   toss_winner      756 non-null    object
#  6   toss_decision    756 non-null    object
#  7   result           756 non-null    object
#  8   dl_applied       756 non-null    int64
#  9   winner           752 non-null    object
#  10  win_by_runs      756 non-null    int64
#  11  win_by_wickets   756 non-null    int64
#  12  player_of_match  752 non-null    object
#  13  venue            756 non-null    object
#  14  umpire1          754 non-null    object
#  15  umpire2          754 non-null    object
#  16  umpire3          119 non-null    object
# ...

# %%
# Filling Null Values with 0
df['city'] = df['city'].fillna(0)
df['winner'] = df['winner'].fillna(0)
df['player_of_match'] = df['player_of_match'].fillna(0)
df['umpire1'] = df['umpire1'].fillna(0)
df['umpire2'] = df['umpire2'].fillna(0)
df['umpire3'] = df['umpire3'].fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             756 non-null    object
#  3   team1            756 non-null    object
#  4   team2            756 non-null    object
#  5   toss_winner      756 non-null    object
#  6   toss_decision    756 non-null    object
#  7   result           756 non-null    object
#  8   dl_applied       756 non-null    int64
#  9   winner           756 non-null    object
#  10  win_by_runs      756 non-null    int64
#  11  win_by_wickets   756 non-null    int64
#  12  player_of_match  756 non-null    object
#  13  venue            756 non-null    object
#  14  umpire1          756 non-null    object
#  15  umpire2          756 non-null    object
#  16  umpire3          756 non-null    object
# ...

# %%
df
# Out:
#         id  season           city                        team1  \
# 0        1    2017      Hyderabad          Sunrisers Hyderabad
# 1        2    2017           Pune               Mumbai Indians
# 2        3    2017         Rajkot                Gujarat Lions
# 3        4    2017         Indore       Rising Pune Supergiant
# 4        5    2017      Bangalore  Royal Challengers Bangalore
# ..     ...     ...            ...                          ...
# 751  11347    2019         Mumbai        Kolkata Knight Riders
# 752  11412    2019        Chennai          Chennai Super Kings
# 753  11413    2019  Visakhapatnam          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam               Delhi Capitals
# 755  11415    2019      Hyderabad               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
winner = df['winner']
toss = df['toss_decision']
# percent of teams who won the match after winning the toss 
# percentage of teams winning after batting first and fielding first . 
winner_based_on_toss = {'Winner':winner,'Toss_decision':toss}
data = pd.DataFrame(winner_based_on_toss)
count=0
for i in data['Toss_decision']:
    if i=='field':
         count=count+1
percent = count/755
per = percent*100
print(per,'% of teams won the game if the chose to field first')
won = 100-per
print(won,'% of Teams won the game by choosing to Bat first')
# Out:
# 61.32450331125828 % of teams won the game if the chose to field first
# 38.67549668874172 % of Teams won the game by choosing to Bat first

# %%
sns.factorplot('Toss_decision',data=data,kind='count')
# The graph shows the number of teams won the match when decided to field and bat first respectively
# Out:
# C:\Users\Pradyot\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Pradyot\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
man_of_the_match = df['player_of_match'].value_counts().head(10)
print(man_of_the_match)
print("\n")
print("The most valueable player in the IPL is Chris Gayle")
# Out:
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# DA Warner         17
# RG Sharma         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
team_win = df['winner'].value_counts().head(10)
print(team_win)
# Most successful and consistent teams in the IPL are as follows
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Name: winner, dtype: int64
